# %%
import numpy as np 
import pandas as pd
from konlpy.tag import Okt

# %%
df = pd.read_csv('data/combined.csv')

# %%
df
# Out:
#                                            symptom class
# 0       질문하겠습니다. 이어폰을 음량을 0으로 하고 끼고만 있어도 귀에 안 좋나요?    FM
# 1                                           독감예방주사    FM
# 2                      목에 음식물 그대로 끼어서 계속 이물감이 있습니다    FM
# 3                                        케겔운동 궁금한것    FM
# 4                                        등 통증 관련문의    FM
# ...                                            ...   ...
# 118082                    병원에 갔더니 갑상선에 대해 조사하던데...   ENT
# 118083                                 비염인지 궁금합니다.   ENT
# 118084                                 비염이 심한데요...   ENT
# 118085                                          귀지   ENT
# 118086                                귀에서 소리가 납니다.   ENT
#
# [118087 rows x 2 columns]

# %%
df[(df['symptom'].isnull())]
# Out:
#        symptom class
# 69111      NaN   LAB
# 102592     NaN   KTM

# %%
df.shape
# Out:
# (118087, 2)

# %%
df.dropna(inplace=True)
df.shape
# Out:
# (118085, 2)

# %%
df
# Out:
#                                            symptom class
# 0       질문하겠습니다. 이어폰을 음량을 0으로 하고 끼고만 있어도 귀에 안 좋나요?    FM
# 1                                           독감예방주사    FM
# 2                      목에 음식물 그대로 끼어서 계속 이물감이 있습니다    FM
# 3                                        케겔운동 궁금한것    FM
# 4                                        등 통증 관련문의    FM
# ...                                            ...   ...
# 118082                    병원에 갔더니 갑상선에 대해 조사하던데...   ENT
# 118083                                 비염인지 궁금합니다.   ENT
# 118084                                 비염이 심한데요...   ENT
# 118085                                          귀지   ENT
# 118086                                귀에서 소리가 납니다.   ENT
#
# [118085 rows x 2 columns]

# %%
df['symptom'] = df['symptom'].str.replace(pat='([ㄱ-ㅎㅏ-ㅣ]+)', repl=r' ', regex=True)
df['symptom'] = df['symptom'].str.replace(pat='[^\w\s]', repl=r' ', regex=True)
df
# Out:
#                                            symptom class
# 0       질문하겠습니다  이어폰을 음량을 0으로 하고 끼고만 있어도 귀에 안 좋나요     FM
# 1                                           독감예방주사    FM
# 2                      목에 음식물 그대로 끼어서 계속 이물감이 있습니다    FM
# 3                                        케겔운동 궁금한것    FM
# 4                                        등 통증 관련문의    FM
# ...                                            ...   ...
# 118082                    병원에 갔더니 갑상선에 대해 조사하던데      ENT
# 118083                                 비염인지 궁금합니다    ENT
# 118084                                 비염이 심한데요      ENT
# 118085                                          귀지   ENT
# 118086                                귀에서 소리가 납니다    ENT
#
# [118085 rows x 2 columns]

# %%
callcount = 0
twitter = Okt()
def to_noun_sentence(text):
    global callcount
    callcount += 1
    if callcount % 100 == 0:
        print(callcount)
    stopwords = ['질문', '문의', '관련', '그대로', '계속', '답변', '선생님', '관련문의',
            '한지', '자주', '좀', '쪽', '자꾸', '요즘', '몇개', '무조건', '하나요',
            '안해','요', '경우', '최근', '및', '몇', '달', '일반', '전날', '저번',
            '말', '일어나지', '며칠', '먹기', '지난번', '글', '때문', '너', '무',
            '오늘', '시', '잔', '뒤', '지속', '막', '것', '이건', '뭔가', '다시', '그',
                '무슨', '안', '난', '도', '기', '후', '거리', '이', '뭘', '저', '뭐', '답젼',
                '평생', '회복', '반', '감사', '의사', '보험', '학생', '제발']
    nouns = twitter.nouns(text)
    for word in nouns:
        if word in stopwords:
            while word in nouns:
                nouns.remove(word)
    return ' '.join(nouns)

# %%
df['nouns'] = df['symptom'].apply(to_noun_sentence)
df.to_csv('data/preprocessed_1.csv', encoding='utf-8', index=False)
# Out:
# 100
# 200
# 300
# 400
# 500
# 600
# 700
# 800
# 900
# 1000
# 1100
# 1200
# 1300
# 1400
# 1500
# 1600
# 1700
# 1800
# 1900
# 2000
# 2100
# 2200
# 2300
# 2400
# 2500
# 2600
# 2700
# 2800
# 2900
# 3000
# 3100
# 3200
# 3300
# 3400
# 3500
# 3600
# 3700
# 3800
# 3900
# 4000
# 4100
# 4200
# 4300
# 4400
# 4500
# 4600
# 4700
# 4800
# 4900
# 5000
# 5100
# 5200
# 5300
# 5400
# 5500
# 5600
# 5700
# 5800
# 5900
# 6000
# 6100
# 6200
# 6300
# 6400
# 6500
# 6600
# 6700
# 6800
# 6900
# 7000
# 7100
# 7200
# 7300
# 7400
# 7500
# 7600
# 7700
# 7800
# 7900
# 8000
# 8100
# 8200
# 8300
# 8400
# 8500
# 8600
# 8700
# 8800
# 8900
# 9000
# 9100
# 9200
# 9300
# 9400
# 9500
# 9600
# 9700
# 9800
# 9900
# 10000
# 10100
# 10200
# 10300
# 10400
# 10500
# 10600
# 10700
# 10800
# 10900
# 11000
# 11100
# 11200
# 11300
# 11400
# 11500
# 11600
# 11700
# 11800
# 11900
# 12000
# 12100
# 12200
# 12300
# 12400
# 12500
# 12600
# 12700
# 12800
# 12900
# 13000
# 13100
# 13200
# 13300
# 13400
# 13500
# 13600
# 13700
# 13800
# ...

# %%
# DERM: 피부과 / GS: 외과 / IP: 호흡기내과 / FM: 가정의학과 / GI: 소화기내과 / OPH: 안과
# NR: 신경과 / ENT: 이비인후과 / PSY : 신경정신과 / HEON: 혈액종양내과 / RHEU: 류마티스내과
# REHM: 재활의학과 / NS: 신경외과 / AN: 마취통증의학과 / DENT: 치과 / PS: 성형외과
# RAD: 영상의학과 / CS: 흉부외과 / INFC: 감염내과 / RAON: 방사선종양학과 / OS: 정형외과 
# EMR: 응급의학과 / ENDO: 내분비내과 / CA: 순환기내과 / KTM: 한방과 / OBGY: 산부인과
# URO: 비뇨기과 / ALL: 알레르기 내과 / NPH: 신장내과 / OEM:직업환경의학과 / COAN: 대장항문외과
# LAB: 진단검사의학과 

# convert class from string to integer
class_to_label = {'DERM': 0, 'GS': 1, 'IP': 2, 'FM': 3, 'GI':4, 'OPH':5,
                  'NR': 6, 'ENT': 7, 'PSY': 8, 'HEON': 9, 'RHEU': 10,
                  'REHM': 11, 'NS': 12, 'AN': 13, 'DENT': 14, 'PS': 15,
                  'RAD': 16, 'CS': 17, 'INFC': 18, 'RAON': 19, 'OS': 20,
                  'EMR': 21, 'ENDO': 22, 'CA': 23, 'KTM': 24, 'OBGY': 25,
                  'URO': 26, 'ALL': 27, 'NPH': 28, 'OEM': 29, 'COAN': 30,
                  'LAB': 31}
df['label'] = df['class'].map(class_to_label)

# %%
df = df[['nouns', 'label']]
df.dropna(inplace=True)
df['label'] = df['label'].astype(int)
df
# Out:
#                nouns  label
# 0           이어폰 음량 귀      3
# 1            독감 예방주사      3
# 2        목 음식물 계속 물감      3
# 3              케겔 운동      3
# 4            등 통증 문의      3
# ...              ...    ...
# 118080  병원 갑상선 대해 조사      7
# 118081            비염      7
# 118082            비염      7
# 118083            귀지      7
# 118084          귀 소리      7
#
# [116879 rows x 2 columns]

# %%
df.to_csv('data/preprocessed_2.csv', encoding='utf-8', index=False)
